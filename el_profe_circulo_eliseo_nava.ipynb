# %% [markdown]
# <a href="https://colab.research.google.com/github/a25308051280032-boop/EPPL-rea-y-per-metro-de-un-circulo-mis-im-genes/blob/main/el_profe_circulo_eliseo_nava.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Iris Chavez NL Fecha 25/Mar/2026♊
# ---
# # Calcular Area y Perimettro de un circulo
# ---
# <img src="https://www.python.org/static/community_logos/python-logo-master-v3-TM.png" width="200">
#
# ![Área del Círculo](https://github.com/a25308051280032-boop/EPPL-rea-y-per-metro-de-un-circulo-mis-im-genes/blob/main/areacirculo.png?raw=true)
#
# ---
# # Formula para calcular el area
# $A=\pi*r^2$
# ---
# ## Formula para calcular perimetro
# $P=2*\pi*r$
# ---
# ## Datos de entrada
# $r$ ?
# ---
# ## Diagrama de flujo en LuciChart
#
# ---
#
# ![DF Lucichart](https://raw.githubusercontent.com/a25308051280032-boop/EPPL-rea-y-per-metro-de-un-circulo-mis-im-genes/refs/heads/main/DF%20Area%20y%20perimetro%20circulo.png)

# %%
# calcular area y perimetro de un circulo
# variables A, P, r
# formulas A = pi*r^2 y P = 2 * pi * r
# Capturar el valor de r
import math
print("Calcular Area y Perimetro de un circulo")
r = float(input("Ingrese el  valor radio: "))
A = math.pi*r**2
P = 2*math.pi*r
print("El area del circulo es: ", A)
print("El perimetro del circulo es: ", P)
print("Iris Chavez NL = 11")
# Out:
# Calcular Area y Perimetro de un circulo
# Ingrese el  valor radio: 4
# El area del circulo es:  50.26548245743669
# El perimetro del circulo es:  25.132741228718345
# Iris Chavez NL = 11

# %% [markdown]
# ### Relacion entre el codigo y el Diagrama de flujo
# ![ Relacion de codigo y DF](https://raw.githubusercontent.com/a25308051280032-boop/EPPL-rea-y-per-metro-de-un-circulo-mis-im-genes/refs/heads/main/area%20perimetro%20de%20un%20circulo.png)
